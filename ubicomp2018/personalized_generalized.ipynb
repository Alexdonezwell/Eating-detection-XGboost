# %%
import os
import pandas as pd
from beyourself import settings
from IPython.display import display, HTML
import datetime
import numpy as np

# %%
concat_list = []
subj_list = ['P103','P105','P107','P108','P110','P114','P116','P118','P120','P121']
latex = ""

average = []

obese = []
nonobese = []

for s in subj_list:
    path = '../data/wild/{}/person_general/{}.csv'.format(s,s)
    df_result = pd.read_csv(path)
    df_result = df_result[['day', 'precision', 'recall', 'fscore']]
    
    if s in ['P103', 'P105','P108','P116','P121']:
        obese.append(df_result['fscore'].iloc[-1])
    else:
        nonobese.append(df_result['fscore'].iloc[-1])

    row = df_result.iloc[-1]
    
    average.append(row[1:])
    
#     latex += s + " & "
    
#     for j in range(1,len(row)):
#         item = row[j]
#         if isinstance(item, str):
#             latex += item
#         elif isinstance(item, datetime.date):
#             latex += item.strftime("%m-%d")
#         else:
#             latex += "{:.1f}".format(100*item)
#         if j != df_result.shape[1] - 1:
#             latex += " & "
#     latex += " \\\\"
#     latex += "\n"

    
    concat_list.append(df_result)
    print(s)
    display(df_result)
# Out:
# P103
#           day  precision    recall    fscore
# 0  2017-06-27   0.967742  0.960000  0.963855
# 1  2017-06-28   0.877670  0.862595  0.870067
# 2  2017-06-29   0.902027  0.606818  0.725543
# 3  2017-06-30   0.924370  0.791367  0.852713
# 4  2017-07-01   0.394089  0.336134  0.362812
# 5  2017-07-02   0.000000  0.000000  0.000000
# 6         Ave   0.832006  0.722187  0.773217
# P105
#           day  precision    recall    fscore
# 0  2017-06-23   0.000000  0.000000  0.000000
# 1  2017-06-24   0.900990  0.938144  0.919192
# 2  2017-06-26   0.616541  0.672131  0.643137
# 3  2017-07-02   0.970760  0.825871  0.892473
# 4  2017-07-03   0.905844  0.975524  0.939394
# 5         Ave   0.853659  0.871514  0.862494
# P107
#           day  precision    recall    fscore
# 0  2017-07-12   0.968750  0.227941  0.369048
# 1  2017-07-17   0.913907  0.500000  0.646370
# 2  2017-07-18   0.957447  0.596026  0.734694
# 3         Ave   0.935018  0.460036  0.616667
# P108
#            day  precision    recall    fscore
# 0   2017-08-04   0.779167  0.912195  0.840449
# 1   2017-08-05   0.454545  0.431034  0.442478
# 2   2017-08-06   0.829060  0.811715  0.820296
# 3   2017-08-07   0.927007  0.881944  0.903915
# 4   2017-08-08   0.924370  0.662651  0.771930
# 5   2017-08-09   0.000000  0.000000  0.000000
# 6   2017-08-10   0.384615  0.833333  0.526316
# 7   2017-08-12   0.906250  0.725000  0.805556
# 8   2017-08-13   0.906250  0.917722  0.911950
# 9   2017-08-14   0.941176  0.668810  0.781955
# 10  2017-08-15   0.956204  0.920375  0.937947
# 11         Ave   0.834049  0.798868  0.816080
# P110
#           day  precision    recall    fscore
# 0  2017-08-05   0.869565  0.606061  0.714286
# 1  2017-08-06   1.000000  1.000000  1.000000
# 2         Ave   0.925620  0.741722  0.823529
# P114
#           day  precision    recall    fscore
# 0  2017-08-09   0.883817  0.887500  0.885655
# 1  2017-08-10   0.691057  0.354167  0.468320
# 2  2017-08-11   0.974737  0.960581  0.967607
# 3  2017-08-14   0.966292  0.924731  0.945055
# 4         Ave   0.917404  0.812718  0.861894
# P116
#           day  precision    recall    fscore
# 0  2017-08-12   0.808824  0.873016  0.839695
# 1  2017-08-13   0.983607  0.967742  0.975610
# 2  2017-08-21   0.658065  0.698630  0.677741
# 3         Ave   0.764085  0.800738  0.781982
# P118
#           day  precision    recall    fscore
# 0  2017-08-19   0.990476  0.932735  0.960739
# 1  2017-08-20   0.000000  0.000000  0.000000
# 2  2017-08-21   0.904348  0.806202  0.852459
# 3  2017-08-22   0.000000  0.000000  0.000000
# 4  2017-08-29   0.961039  0.886228  0.922118
# 5  2017-08-30   1.000000  0.873563  0.932515
# 6  2017-08-31   0.000000  0.000000  0.000000
# 7         Ave   0.887237  0.871046  0.879067
# P120
#            day  precision    recall    fscore
# 0   2017-08-24   0.891041  0.757202  0.818687
# 1   2017-08-25   0.000000  0.000000  0.000000
# 2   2017-08-26   0.783476  0.961538  0.863422
# 3   2017-08-27   0.983108  0.873874  0.925278
# 4   2017-08-28   0.660920  0.927419  0.771812
# 5   2017-08-29   0.893382  0.812709  0.851138
# 6   2017-08-30   0.837302  0.913420  0.873706
# 7   2017-08-31   0.461538  0.705882  0.558140
# 8   2017-09-01   0.000000  0.000000  0.000000
# 9   2017-09-02   0.747082  0.868778  0.803347
# 10  2017-09-03   0.876712  0.618357  0.725212
# 11  2017-09-04   0.470149  0.692308  0.560000
# 12  2017-09-05   0.434650  0.756614  0.552124
# 13         Ave   0.752159  0.828697  0.788575
# P121
#           day  precision    recall    fscore
# 0  2017-08-24   0.969697  0.953191  0.961373
# 1  2017-08-26   0.355731  0.532544  0.426540
# 2  2017-08-27   0.945813  0.580060  0.719101
# 3         Ave   0.736536  0.688435  0.711674

# %%
df_average = pd.DataFrame(average)
total_ave = df_average.mean().as_matrix()

latexnew = latex + "Ave & "
for i in total_ave:
    latexnew += "{:.1f}".format(100*i)
    latexnew += " & "

print(latexnew)
# Out:
# P103 & 83.2 & 72.2 & 77.3 \\
# P105 & 85.4 & 87.2 & 86.2 \\
# P107 & 93.5 & 46.0 & 61.7 \\
# P108 & 83.4 & 79.9 & 81.6 \\
# P110 & 92.6 & 74.2 & 82.4 \\
# P114 & 91.7 & 81.3 & 86.2 \\
# P116 & 76.4 & 80.1 & 78.2 \\
# P118 & 88.7 & 87.1 & 87.9 \\
# P120 & 75.2 & 82.9 & 78.9 \\
# P121 & 73.7 & 68.8 & 71.2 \\
# Ave & 84.4 & 76.0 & 79.2 &

# %%
print(np.mean(obese))
print(np.mean(nonobese))
# Out:
# 0.7890892166617529
# 0.7939464328693401
